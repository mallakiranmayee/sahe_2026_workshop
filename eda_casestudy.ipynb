# %% [markdown]
# Objective of Exploratory Data Analysis
# -->To bring out the quality of the data and make it ready for Machine Learning Modeling

# %%
#import libraries 
import numpy as np #Faster Data processing (arrays)
import pandas as pd #EDA Purpose

# %%
# !pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in .\Lib\site-packages (2.5.1)
# Requirement already satisfied: pandas in .\Lib\site-packages (3.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in .\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#loading the data
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#understanding the data -->info(),describe(),columns(),unique(),value_counts()
data.info #complete information about dataset
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
#reading columns
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
#we will seperate the columns
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
#we will seperate the columns
data.dtypes
data.select_dtypes(include='object')
# Out:
# C:\Users\24EU08038\AppData\Local\Temp\ipykernel_2324\2620324336.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
#we will seperate the columns
data.dtypes
data.select_dtypes(include='integer')
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
#we will seperate the columns
data.dtypes
data.select_dtypes(include='object')
data.select_dtypes(include=['int','float'])
# Out:
# C:\Users\24EU08038\AppData\Local\Temp\ipykernel_2324\2828472862.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#total number of passengers in the ship
print('total number of passengers in the ship are',len(data))
# Out:
# total number of passengers in the ship are 891

# %%
#statistical distribution -->describe()
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# Out:
# C:\Users\24EU08038\AppData\Local\Temp\ipykernel_2324\3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data.describe(include='str')
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
#we try to understand the unique values in the column
data['sex'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 #we try to understand the unique values in the column
# ----> 2 data['sex'].unique()
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'sex'

# %%
#we try to understand the unique values in the column
data['Sex'].unique()
# Out:
# <ArrowStringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
data['Embarked'].unique() #embarked is place of travel
# Out:
# <ArrowStringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
data['survived'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'survived'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data['survived'].unique()
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'survived'

# %%
data['Survived'].unique()
# Out:
# array([0, 1])

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
#count of each unique value
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
data['Pclass'].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Age'].value_counts()
data['Age'].value_counts(ascending=True)
# Out:
# Age
# 66.0     1
# 14.5     1
# 70.5     1
# 12.0     1
# 36.5     1
#         ..
# 19.0    25
# 30.0    25
# 18.0    26
# 22.0    27
# 24.0    30
# Name: count, Length: 88, dtype: int64

# %%
data['Ticket'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data['Ticket'].value_count()
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
data['Ticket'].value_counts()
# Out:
# Ticket
# 347082             7
# 1601               7
# CA. 2343           7
# 3101295            6
# CA 2144            6
#                   ..
# SOTON/OQ 392076    1
# 211536             1
# 112053             1
# 111369             1
# 370376             1
# Name: count, Length: 681, dtype: int64

# %%
data['Age'].value.counts().head(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data['Age'].value.counts().head(30)
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
#to get random samples in the dataset
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 266          267         0       3
# 415          416         0       3
# 120          121         0       2
# 45            46         0       3
# 343          344         0       2
# 110          111         0       1
# 720          721         1       2
# 631          632         0       3
# 323          324         1       2
# 58            59         1       2
# 311          312         1       1
# 526          527         1       2
# 378          379         0       3
# 501          502         0       3
# 12            13         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 266                          Panula, Mr. Ernesti Arvid    male  16.0      4
# 415            Meek, Mrs. Thomas (Annie Louise Rowley)  female   NaN      0
# 120                        Hickman, Mr. Stanley George    male  21.0      2
# 45                            Rogers, Mr. William John    male   NaN      0
# 343         Sedgwick, Mr. Charles Frederick Waddington    male  25.0      0
# 110                     Porter, Mr. Walter Chamberlain    male  47.0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female   6.0      0
# 631                        Lundahl, Mr. Johan Svensson    male  51.0      0
# 323  Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...  female  22.0      1
# 58                        West, Miss. Constance Mirium  female   5.0      1
# 311                         Ryerson, Miss. Emily Borie  female  18.0      2
# 526                               Ridsdale, Miss. Lucy  female  50.0      0
# 378                                Betros, Mr. Tannous    male  20.0      0
# 501                                Canavan, Miss. Mary  female  21.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
#
#      Parch           Ticket      Fare            Cabin Embarked
# 266      1          3101295   39.6875              NaN        S
# 415      0           343095    8.0500              NaN        S
# 120      0     S.O.C. 14879   73.5000              NaN        S
# 45       0  S.C./A.4. 23567    8.0500              NaN        S
# 343      0           244361   13.0000              NaN        S
# 110      0           110465   52.0000             C110        S
# 720      1           248727   33.0000              NaN        S
# 631      0           347743    7.0542              NaN        S
# 323      1           248738   29.0000              NaN        S
# 58       2       C.A. 34651   27.7500              NaN        S
# 311      2         PC 17608  262.3750  B57 B59 B63 B66        C
# 526      0      W./C. 14258   10.5000              NaN        S
# 378      0             2648    4.0125              NaN        C
# 501      0           364846    7.7500              NaN        Q
# 12       0        A/5. 2151    8.0500              NaN        S

# %%
#datavisualization -->matplotlib,seaborn,plotly
import matplotlib.pyplot as plt #!pip install matplotlib
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#!pip install matplotlib

# %%
#distribution of Age
plt.hist(data['Age'],bins=15,color='red')
plt.title("Age Distribution")
plt.show()

# %%
#Dristribution of Age 
counts,edges,bars = plt.hist(data['Age'],bins=15,color='red')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age Dristribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
#bar plot represemtation
data['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
data['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
data['Age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
plt.bar(data['Survived'],data['Sex'])
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived Distribution")
plt.show()

# %%
index = data['Survived'].value_counts().keys().tolist()
print(index)
labels = data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
plt.pie(x = labels,
        labels = ['Dead','Alive'],
        colors = ['red','yellow'],
        autopct="%.1f%")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 plt.pie(x = labels,
#       2         labels = ['Dead','Alive'],
#       3         colors = ['red','yellow'],
#       4         autopct="%.1f%")
#
#     [... skipping hidden 1 frame]
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\matplotlib\pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
#    3993         colors=colors,
#    3994         autopct=autopct,
#    3995         pctdistance=pctdistance,
#    3996         shadow=shadow,
#    3997         labeldistance=labeldistance,
#    3998         startangle=startangle,
#    3999         radius=radius,
#    4000         counterclock=counterclock,
#    4001         wedgeprops=wedgeprops,
#    4002         textprops=textprops,
#    4003         center=center,
#    4004         frame=frame,
#    4005         rotatelabels=rotatelabels,
#    4006         normalize=normalize,
#    4007         hatch=hatch,
#    4008         **({"data": data} if data is not None else {}),
#    4009     )
#
#     [... skipping hidden 2 frame]
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\matplotlib\axes\_axes.py:3753, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3751 for frac in fracs:
#    3752     if isinstance(autopct, str):
# -> 3753         s = autopct % (100. * frac)
#    3754     elif callable(autopct):
#    3755         s = autopct(100. * frac)
#
# ValueError: incomplete format

# %%
plt.pie(x = labels,
        labels = ['Dead','Alive'],
        colors = ['red','yellow'],
        autopct="%.1f%",
        shadow=True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 plt.pie(x = labels,
#       2         labels = ['Dead','Alive'],
#       3         colors = ['red','yellow'],
#       4         autopct="%.1f%",
#
#     [... skipping hidden 1 frame]
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\matplotlib\pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
#    3993         colors=colors,
#    3994         autopct=autopct,
#    3995         pctdistance=pctdistance,
#    3996         shadow=shadow,
#    3997         labeldistance=labeldistance,
#    3998         startangle=startangle,
#    3999         radius=radius,
#    4000         counterclock=counterclock,
#    4001         wedgeprops=wedgeprops,
#    4002         textprops=textprops,
#    4003         center=center,
#    4004         frame=frame,
#    4005         rotatelabels=rotatelabels,
#    4006         normalize=normalize,
#    4007         hatch=hatch,
#    4008         **({"data": data} if data is not None else {}),
#    4009     )
#
#     [... skipping hidden 2 frame]
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\matplotlib\axes\_axes.py:3753, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3751 for frac in fracs:
#    3752     if isinstance(autopct, str):
# -> 3753         s = autopct % (100. * frac)
#    3754     elif callable(autopct):
#    3755         s = autopct(100. * frac)
#
# ValueError: incomplete format

# %%
plt.pie(x = labels,
        labels = ['Dead','Alive'],
        colors = ['red','yellow'],
        autopct="%.1f%",
        shadow=True)
plt.title("Survived Distribution")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 plt.pie(x = labels,
#       2         labels = ['Dead','Alive'],
#       3         colors = ['red','yellow'],
#       4         autopct="%.1f%",
#
#     [... skipping hidden 1 frame]
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\matplotlib\pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
#    3993         colors=colors,
#    3994         autopct=autopct,
#    3995         pctdistance=pctdistance,
#    3996         shadow=shadow,
#    3997         labeldistance=labeldistance,
#    3998         startangle=startangle,
#    3999         radius=radius,
#    4000         counterclock=counterclock,
#    4001         wedgeprops=wedgeprops,
#    4002         textprops=textprops,
#    4003         center=center,
#    4004         frame=frame,
#    4005         rotatelabels=rotatelabels,
#    4006         normalize=normalize,
#    4007         hatch=hatch,
#    4008         **({"data": data} if data is not None else {}),
#    4009     )
#
#     [... skipping hidden 2 frame]
#
# File C:\ML_Workshop\ml_workshop_env\Lib\site-packages\matplotlib\axes\_axes.py:3753, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3751 for frac in fracs:
#    3752     if isinstance(autopct, str):
# -> 3753         s = autopct % (100. * frac)
#    3754     elif callable(autopct):
#    3755         s = autopct(100. * frac)
#
# ValueError: incomplete format

# %%
#pie Chart
plt.pie(x= [577,314],
        labels=['M','F'],
        colors=['orange','lightgreen'],
        autopct="%.1f%%",
       shadow=True)
plt.title("Gender Distribution")
plt.legend()
plt.show()

# %%
plt.scatter(x=data['Age'],
            y=data['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age vs Fare Distribution")
plt.show()

# %%
# !pip install cufflinks
# Out:
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in .\Lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in .\Lib\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in .\Lib\site-packages (from cufflinks) (6.9.0)
# Requirement already satisfied: six>=1.9.0 in .\Lib\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Collecting setuptools>=34.4.1 (from cufflinks)
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: ipython>=5.3.0 in .\Lib\site-packages (from cufflinks) (9.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in .\Lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.16.1)
# Requirement already satisfied: wcwidth>=0.1.4 in .\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in .\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\Lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in .\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.24.0)
# Requirement already satisfied: packaging in .\Lib\site-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: executing>=1.2.0 in .\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in .\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68558 sha256=86d597b16362e639b1dddb21489120f2c4b3fc0e2673b80bdb7c8d04779605d6
#   Stored in directory: c:\users\24eu08038\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# Installing collected packages: colorlover, setuptools, cufflinks
#
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    ---------------------------------------- 3/3 [cufflinks]
#
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3 setuptools-83.0.0

# %%
#pip install plotly 
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in .\Lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in .\Lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in .\Lib\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in .\Lib\site-packages (from cufflinks) (6.9.0)
# Requirement already satisfied: six>=1.9.0 in .\Lib\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in .\Lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in .\Lib\site-packages (from cufflinks) (83.0.0)
# Requirement already satisfied: ipython>=5.3.0 in .\Lib\site-packages (from cufflinks) (9.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in .\Lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in .\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.16.1)
# Requirement already satisfied: wcwidth>=0.1.4 in .\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in .\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\Lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in .\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.24.0)
# Requirement already satisfied: packaging in .\Lib\site-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: executing>=1.2.0 in .\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in .\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)

# %%
import plotly

# %%
import plotly as py

# %%
import plotly.graph_objects as go #for interactive graphs

# %%
#visualize histograms
trace=go.Histogram(x=data['Age'],
                   nbinsx=20,
                   marker={'color':'red'})
#layout define for the graph
layout=go.Layout(title="Age distribution")
#we combine race with the layout to display the figure
fig=go.Figure(data=trace,layout=layout)
fig

# %%
print(index)
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
trace=go.Pie(labels=['Dead','Alive'],values=[549,342])
layout=go.Layout(title='Survived Distribution')
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
#box plot and scatter plot
trace=go.Box(x=data['Pclass'],
            y=data['Age'],
            marker={'color':'purple'})
layout=go.Layout(title="Age vs Pclass Distribution")
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
trace = go.Scatter(x=data['Age'],y=data['Fare'],
                   marker={'color':'violet'})
layout = go.Layout(
    title="Age vs Fare Distribution")
fig = go.Figure(data=trace,layout=layout)
fig.show()

# %%
trace = go.Scatter(x=data['Age'],y=data['Fare'],
                   mode='markers',
                   marker={'color':'violet'})
layout = go.Layout(
    title="Age vs Fare Distribution")
fig = go.Figure(data=trace,layout=layout)
fig.show()

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#We can fill the Age column missing values with mean 
data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True)
# Out:
# C:\Users\24EU08038\AppData\Local\Temp\ipykernel_2324\1598260387.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data['Embarked']=data['Embarked'].fillna('S')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data.drop(columns=['Cabin'],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Embarked
# 0      1      0         A/5 21171   7.2500        S
# 1      1      0          PC 17599  71.2833        C
# 2      0      0  STON/O2. 3101282   7.9250        S
# 3      1      0            113803  53.1000        S
# 4      0      0            373450   8.0500        S
# 5      0      0            330877   8.4583        Q
# 6      0      0             17463  51.8625        S
# 7      3      1            349909  21.0750        S
# 8      0      2            347742  11.1333        S
# 9      1      0            237736  30.0708        C

# %%
pclass = pd.get_dummies(data['Pclass'])
pclass
# Out:
#          1      2      3
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3     True  False  False
# 4    False  False   True
# ..     ...    ...    ...
# 886  False   True  False
# 887   True  False  False
# 888  False  False   True
# 889   True  False  False
# 890  False  False   True
#
# [891 rows x 3 columns]

# %%
pclass = pd.get_dummies(data['Pclass'],drop_first=True)
pclass
# Out:
#          2      3
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False  False
# 4    False   True
# ..     ...    ...
# 886   True  False
# 887  False  False
# 888  False   True
# 889  False  False
# 890  False   True
#
# [891 rows x 2 columns]

# %%
pclass = pd.get_dummies(data['Pclass'],drop_first=True,dtype=int)
pclass
# Out:
#      2  3
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  0
# 4    0  1
# ..  .. ..
# 886  1  0
# 887  0  0
# 888  0  1
# 889  0  0
# 890  0  1
#
# [891 rows x 2 columns]

# %%
gender=pd.get_dummies(data['Sex'],drop_first=True,dtype=int)
gender
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
embarked=pd.get_dummies(data['Embarked'],drop_first=True,dtype=int)
embarked
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
#Concatenation of all tables
final_data=pd.concat([data,pclass,gender,embarked],axis=1)
final_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked  2  3  male  Q  S
# 0        1      0         A/5 21171   7.2500        S  0  1     1  0  1
# 1        1      0          PC 17599  71.2833        C  0  0     0  0  0
# 2        0      0  STON/O2. 3101282   7.9250        S  0  1     0  0  1
# 3        1      0            113803  53.1000        S  0  0     0  0  1
# 4        0      0            373450   8.0500        S  0  1     1  0  1
# ..     ...    ...               ...      ...      ... .. ..   ... .. ..
# 886      0      0            211536  13.0000        S  1  0     1  0  1
# 887      0      0            112053  30.0000        S  0  0     0  0  1
# 888      1      2        W./C. 6607  23.4500        S  0  1     0  0  1
# 889      0      0            111369  30.0000        C  0  0     1  0  0
# 890      0      0            370376   7.7500        Q  0  1     1  1  0
#
# [891 rows x 16 columns]
